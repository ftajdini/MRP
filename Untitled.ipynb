# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %% [raw]
# Data loading and cleaning

# %%
df = pd.read_csv('hcvdat0.csv')

# %%
df.head()
# Out:
#    Unnamed: 0       Category  Age Sex   ALB   ALP   ALT   AST   BIL    CHE  \
# 0           1  0=Blood Donor   32   m  38.5  52.5   7.7  22.1   7.5   6.93
# 1           2  0=Blood Donor   32   m  38.5  70.3  18.0  24.7   3.9  11.17
# 2           3  0=Blood Donor   32   m  46.9  74.7  36.2  52.6   6.1   8.84
# 3           4  0=Blood Donor   32   m  43.2  52.0  30.6  22.6  18.9   7.33
# 4           5  0=Blood Donor   32   m  39.2  74.1  32.6  24.8   9.6   9.15
#
#    CHOL   CREA   GGT  PROT
# 0  3.23  106.0  12.1  69.0
# 1  4.80   74.0  15.6  76.5
# 2  5.20   86.0  33.2  79.3
# 3  4.74   80.0  33.8  75.7
# 4  4.32   76.0  29.9  68.7

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
def convert_category(category):
    if category == '0=Blood Donor':
        return 0
    else:
        return 1

# Apply the function to the 'Category' column
df['Category'] = df['Category'].apply(convert_category)

# %%
# Change 'm' to 'Male' and 'f' to 'Female' in the Sex column
df['Sex'] = df['Sex'].map({'m': 'Male', 'f': 'Female'})

# %%
df.head()
# Out:
#    Category  Age   Sex   ALB   ALP   ALT   AST   BIL    CHE  CHOL   CREA  \
# 0         0   32  Male  38.5  52.5   7.7  22.1   7.5   6.93  3.23  106.0
# 1         0   32  Male  38.5  70.3  18.0  24.7   3.9  11.17  4.80   74.0
# 2         0   32  Male  46.9  74.7  36.2  52.6   6.1   8.84  5.20   86.0
# 3         0   32  Male  43.2  52.0  30.6  22.6  18.9   7.33  4.74   80.0
# 4         0   32  Male  39.2  74.1  32.6  24.8   9.6   9.15  4.32   76.0
#
#     GGT  PROT
# 0  12.1  69.0
# 1  15.6  76.5
# 2  33.2  79.3
# 3  33.8  75.7
# 4  29.9  68.7

# %%
df.shape
# Out:
# (615, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615 entries, 0 to 614
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  615 non-null    int64
#  1   Age       615 non-null    int64
#  2   Sex       615 non-null    object
#  3   ALB       614 non-null    float64
#  4   ALP       597 non-null    float64
#  5   ALT       614 non-null    float64
#  6   AST       615 non-null    float64
#  7   BIL       615 non-null    float64
#  8   CHE       615 non-null    float64
#  9   CHOL      605 non-null    float64
#  10  CREA      615 non-null    float64
#  11  GGT       615 non-null    float64
#  12  PROT      614 non-null    float64
# dtypes: float64(10), int64(2), object(1)
# memory usage: 62.6+ KB

# %%
# Display the number of missing values for each column
missing_values = df.isnull().sum()

# Print the result
print(missing_values)
# Out:
# Category     0
# Age          0
# Sex          0
# ALB          1
# ALP         18
# ALT          1
# AST          0
# BIL          0
# CHE          0
# CHOL        10
# CREA         0
# GGT          0
# PROT         1
# dtype: int64

# %%
# Selecting the columns with missing values for imputation
columns_with_missing_values = ['ALB', 'ALP', 'ALT', 'CHOL', 'PROT']

# Initialize the IterativeImputer with specific parameters
imputer = IterativeImputer(max_iter=10, random_state=0)

# Perform imputation
df[columns_with_missing_values] = imputer.fit_transform(df[columns_with_missing_values])

# Check for any remaining missing values
missing_values_after_imputation = df.isnull().sum()
print(missing_values_after_imputation)
# Out:
# Category    0
# Age         0
# Sex         0
# ALB         0
# ALP         0
# ALT         0
# AST         0
# BIL         0
# CHE         0
# CHOL        0
# CREA        0
# GGT         0
# PROT        0
# dtype: int64

# %%
last_20_rows = df.tail(20)
print(last_20_rows)
# Out:
#      Category  Age     Sex        ALB         ALP    ALT    AST    BIL   CHE  \
# 595         1   56    Male  27.000000   81.100000   17.0  319.8   37.0  1.42
# 596         1   56    Male  23.000000  105.600000    5.1  123.0   43.0  1.80
# 597         1   56    Male  30.000000   40.400000    0.9   80.3  119.0  1.88
# 598         1   58    Male  31.000000  143.100000    7.0  181.8   58.0  3.29
# 599         1   59    Male  36.000000   49.700000    5.2  110.1   37.0  2.29
# 600         1   59    Male  27.000000   73.800000    4.0   65.2  209.0  2.47
# 601         1   59    Male  31.000000   86.300000    5.4   95.4  117.0  1.57
# 602         1   61    Male  39.000000  102.900000   27.3  143.2   15.0  5.38
# 603         1   65    Male  45.663815   69.925815   40.0   54.0   13.0  7.50
# 604         1   74    Male  23.000000   34.100000    2.1   90.4   22.0  2.50
# 605         1   42  Female  33.000000   79.000000    3.7   55.7  200.0  1.72
# ...

# %%
df['Disease'] = df['Category']


# Calculate the counts of each group
gender_disease_counts = df.groupby(['Sex', 'Disease']).size().unstack(fill_value=0)

# Calculate the percentage of each group
gender_disease_percent = gender_disease_counts.div(gender_disease_counts.sum(axis=1), axis=0) * 100

# Reset index for plotting
gender_disease_percent = gender_disease_percent.reset_index()

# Rename the columns for clarity
gender_disease_percent.columns = ['Sex', 'Healthy', 'Diseased']

# Plot the grouped bar chart
gender_disease_percent.plot(x='Sex', kind='bar', stacked=False, color=['#1F6357', '#C34A2C'])
plt.title('Percentage of Healthy and Diseased Individuals by Gender')
plt.xlabel('Sex')
plt.ylabel('Percentage')
plt.legend(['Healthy', 'Diseased'], title='Health Status')
plt.show()

# %%
# Plot count plot for the Disease variable
plt.figure(figsize=(6, 6))
sns.countplot(x='Disease', data=df, palette=['#1F6357', '#C34A2C'])
plt.title('Count Plot of Disease Status')
plt.xlabel('Disease')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['Healthy', 'Diseased'])
plt.show()

# %%
# Create age bins (groups)
bins = [18 ,25, 35, 45, 55, 65, 75, 85]
labels = ['18-24','25-34', '35-44', '45-54', '55-64', '65-74', '75-84']
df['Age Group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

# Count the number of occurrences in each age group
age_group_counts = df['Age Group'].value_counts(sort=False)

# Plot the distribution of age groups
plt.figure(figsize=(10, 6))
age_group_counts.plot(kind='bar', color='#15317E')
plt.title('Distribution of Age Groups')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Calculate the counts of each group
age_group_disease_counts = df.groupby(['Age Group', 'Disease']).size().unstack(fill_value=0)

# Reset index for plotting
age_group_disease_counts = age_group_disease_counts.reset_index()

# Rename the columns for clarity
age_group_disease_counts.columns = ['Age Group', 'Healthy', 'Diseased']
print(age_group_disease_counts)
# Out:
#   Age Group  Healthy  Diseased
# 0     18-24        0         2
# 1     25-34       57         9
# 2     35-44      160        15
# 3     45-54      194        25
# 4     55-64       98        24
# 5     65-74       21         6
# 6     75-84        3         1

# %%
# Plot the grouped bar chart
age_group_disease_counts.plot(x='Age Group', kind='bar', stacked=False, color=['#1F6357', '#C34A2C'], figsize=(10, 6))
plt.title('Number of Healthy and Diseased Individuals by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.legend(['Healthy', 'Diseased'], title='Health Status')
plt.xticks(rotation=45)
plt.show()

# %%
def categorize_chol(chol):
    if chol < 5.2:
        return 'Normal'
    elif 5.2 <= chol < 6.2:
        return 'Borderline High'
    elif 6.2 <= chol < 7.8:
        return 'High'
    else:
        return 'Very High'

# Apply the function to categorize cholesterol levels
df['Cholesterol Category'] = df['CHOL'].apply(categorize_chol)

# Calculate the counts of each group
chol_sex_counts = df.groupby(['Sex', 'Cholesterol Category']).size().unstack(fill_value=0)

# Print the counts of each group
print("Counts of Cholesterol Categories by Gender:")
print(chol_sex_counts)

# Reset index for plotting
chol_sex_counts = chol_sex_counts.reset_index()

# Plot the grouped bar chart
chol_sex_counts.plot(x='Sex', kind='bar', stacked=False, color=['#1F6357', '#C34A2C', '#FFDD44', '#FF0000'], figsize=(10, 6))
plt.title('Cholesterol Levels Among Males and Females')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.legend(['Normal', 'Borderline High', 'High', 'Very High'], title='Cholesterol Level')
plt.xticks(rotation=0)
plt.show()
# Out:
# Counts of Cholesterol Categories by Gender:
# Cholesterol Category  Borderline High  High  Normal  Very High
# Sex
# Female                             84    45     105          4
# Male                              117    76     174         10

# %%
# Create a function to categorize cholesterol levels
def categorize_chol(chol):
    if chol < 5.2:
        return 'Normal'
    elif 5.2 <= chol < 6.2:
        return 'Borderline High'
    elif 6.2 <= chol < 7.8:
        return 'High'
    else:
        return 'Very High'

# Apply the function to categorize cholesterol levels
df['Cholesterol Category'] = df['CHOL'].apply(categorize_chol)

# Calculate the counts of each group
chol_sex_counts = df.value_counts(['Sex', 'Cholesterol Category']).reset_index().rename(columns={0: "count"})

# Print the counts of each group
print("Counts of Cholesterol Categories by Gender:")
print(chol_sex_counts)

# Plot the sunburst chart with larger dimensions
fig = px.sunburst(
    chol_sex_counts,
    path=['Sex', 'Cholesterol Category'],  
    values='count', 
    color='count',  
    color_continuous_scale='RdBu',  
    title='Cholesterol Levels Among Males and Females'
)
fig.update_layout(width=1200, height=800)
fig.show()
# Out:
# Counts of Cholesterol Categories by Gender:
#       Sex Cholesterol Category  count
# 0    Male               Normal    174
# 1    Male      Borderline High    117
# 2  Female               Normal    105
# 3  Female      Borderline High     84
# 4    Male                 High     76
# 5  Female                 High     45
# 6    Male            Very High     10
# 7  Female            Very High      4

# %%
# Filter the dataset to include only diseased individuals
df_diseased = df[df['Category'] == 1].copy()

# Create a function to categorize cholesterol levels
def categorize_chol(chol):
    if pd.isna(chol):
        return 'Unknown'
    elif chol < 5.2:
        return 'Normal'
    elif 5.2 <= chol < 6.2:
        return 'Borderline High'
    elif 6.2 <= chol < 7.8:
        return 'High'
    else:
        return 'Very High'

# Apply the function to categorize cholesterol levels
df_diseased['Cholesterol Category'] = df_diseased['CHOL'].apply(categorize_chol)

# Calculate the counts of each group
chol_sex_counts_diseased = df_diseased.value_counts(['Sex', 'Cholesterol Category']).reset_index().rename(columns={0: "count"})

# Plot the sunburst chart with larger dimensions
fig = px.sunburst(
    chol_sex_counts_diseased,
    path=['Sex', 'Cholesterol Category'],  
    values='count', 
    color='count',  
    color_continuous_scale='RdBu',  
    title='Cholesterol Levels Among Diseased Individuals'
)
fig.update_layout(width=1200, height=800)
fig.show()

# %%
# Violin plot of ALP levels by Sex
plt.figure(figsize=(10, 6))
sns.violinplot(x='Sex', y='ALP', data=df)
plt.title('Violin Plot of ALP Levels by Sex')
plt.xlabel('Sex')
plt.ylabel('ALP Levels (U/L)')
plt.show()

# %%
# Scatter plot of ALP levels by Age
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='ALP', hue='Sex', data=df)
plt.title('Scatter Plot of ALP Levels by Age and Sex')
plt.xlabel('Age')
plt.ylabel('ALP Levels (U/L)')
plt.show()

# %%
# Density plot of ALP levels by Sex
plt.figure(figsize=(10, 6))
sns.kdeplot(data=df, x='ALP', hue='Sex', fill=True)
plt.title('Density Plot of ALP Levels by Sex')
plt.xlabel('ALP Levels (U/L)')
plt.ylabel('Density')
plt.show()

# %%
# Map the Category column to a more understandable format
df['Disease Status'] = df['Category'].map({0: 'Healthy', 1: 'Diseased'})

# Create a function to categorize ALT levels
def categorize_alt(alt):
    if pd.isna(alt):
        return 'Unknown'
    elif alt < 7 or alt > 56:
        return 'Abnormal'
    else:
        return 'Normal'

# Apply the function to categorize ALT levels
df['ALT Category'] = df['ALT'].apply(categorize_alt)

# Filter the dataset to include only abnormal ALT levels
df_abnormal_alt = df[df['ALT Category'] == 'Abnormal']

# Calculate the counts of each group
alt_disease_counts = df_abnormal_alt['Disease Status'].value_counts().reset_index().rename(columns={'index': 'Disease Status', 'Disease Status': 'Count'})

# Print the counts of each group
print("Counts of Abnormal ALT Levels by Disease Status:")
print(alt_disease_counts)
# Out:
# Counts of Abnormal ALT Levels by Disease Status:
#       Count  count
# 0  Diseased     36
# 1   Healthy     21

# %%
df['Disease Status'] = df['Category'].map({0: 'Healthy', 1: 'Diseased'})

# Create a function to categorize ALT levels
def categorize_alt(alt):
    if pd.isna(alt):
        return 'Unknown'
    elif alt < 7 or alt > 56:
        return 'Abnormal'
    else:
        return 'Normal'

# Apply the function to categorize ALT levels
df['ALT Category'] = df['ALT'].apply(categorize_alt)

# Filter the dataset to include only abnormal ALT levels
df_abnormal_alt = df[df['ALT Category'] == 'Abnormal']

# Calculate the counts of each group
alt_disease_counts = df_abnormal_alt.value_counts(['Disease Status', 'Sex']).reset_index().rename(columns={0: "count"})

# Print the counts of each group
print("Counts of Abnormal ALT Levels by Disease Status and Sex:")
print(alt_disease_counts)

# Plot the grouped bar chart
plt.figure(figsize=(12, 8))
sns.barplot(x='Disease Status', y='count', hue='Sex', data=alt_disease_counts, palette='viridis')
plt.title('Counts of Abnormal ALT Levels by Disease Status and Sex')
plt.xlabel('Disease Status')
plt.ylabel('Count')
plt.legend(title='Sex')
plt.show()
# Out:
# Counts of Abnormal ALT Levels by Disease Status and Sex:
#   Disease Status     Sex  count
# 0       Diseased    Male     23
# 1        Healthy    Male     17
# 2       Diseased  Female     13
# 3        Healthy  Female      4

# %%
# Map the Category column to a more understandable format
df['Disease Status'] = df['Category'].map({0: 'Healthy', 1: 'Diseased'})

# Create a function to categorize ALT levels
def categorize_alt(alt):
    if pd.isna(alt):
        return 'Unknown'
    elif alt < 7 or alt > 56:
        return 'Abnormal'
    else:
        return 'Normal'

# Apply the function to categorize ALT levels
df['ALT Category'] = df['ALT'].apply(categorize_alt)

# Filter the dataset to include only abnormal ALT levels
df_abnormal_alt = df[df['ALT Category'] == 'Abnormal']

# Calculate the counts of each group
alt_disease_sex_counts = df_abnormal_alt.value_counts(['Disease Status', 'Sex']).reset_index().rename(columns={0: "Count"})

# Print the counts of each group
print("Counts of Abnormal ALT Levels by Disease Status and Sex:")
print(alt_disease_sex_counts)

# Plot the bubble chart
plt.figure(figsize=(12, 8))
bubble_chart = sns.scatterplot(x='Disease Status', y='Sex', size='Count', data=alt_disease_sex_counts, legend=False, sizes=(100, 1000), alpha=0.6)
for line in range(0, alt_disease_sex_counts.shape[0]):
    bubble_chart.text(alt_disease_sex_counts['Disease Status'][line], alt_disease_sex_counts['Sex'][line], alt_disease_sex_counts['Count'][line], horizontalalignment='left', size='medium', color='black', weight='semibold')
plt.title('Counts of Abnormal ALT Levels by Disease Status and Sex')
plt.xlabel('Disease Status')
plt.ylabel('Sex')
plt.show()
# Out:
# Counts of Abnormal ALT Levels by Disease Status and Sex:
#   Disease Status     Sex  count
# 0       Diseased    Male     23
# 1        Healthy    Male     17
# 2       Diseased  Female     13
# 3        Healthy  Female      4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[109], line 28
#      26 # Plot the bubble chart
#      27 plt.figure(figsize=(12, 8))
# ---> 28 bubble_chart = sns.scatterplot(x='Disease Status', y='Sex', size='Count', data=alt_disease_sex_counts, legend=False, sizes=(100, 1000), alpha=0.6)
#      29 for line in range(0, alt_disease_sex_counts.shape[0]):
#      30     bubble_chart.text(alt_disease_sex_counts['Disease Status'][line], alt_disease_sex_counts['Sex'][line], alt_disease_sex_counts['Count'][line], horizontalalignment='left', size='medium', color='black', weight='semibold')
#
# ...

# %%
# List of continuous variables
continuous_vars = ['ALB', 'ALP', 'ALT', 'AST', 'BIL', 'CHE', 'CHOL', 'CREA', 'GGT', 'PROT']

# Plot histograms for continuous variables
df[continuous_vars].hist(bins=20, figsize=(15, 10), color='#15317E')
plt.suptitle('Histograms of Continuous Variables')
plt.show()

# %%
# Compute the correlation matrix
corr = df[continuous_vars].corr()

# Generate a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix of Continuous Variables')
plt.show()

# %%
columns_to_visualize = ['ALB', 'ALP', 'ALT', 'AST', 'BIL', 'CHE', 'CHOL', 'CREA', 'GGT', 'PROT']

# Plot histograms for each column
df[columns_to_visualize].hist(bins=20, figsize=(15, 10))
plt.suptitle('Histograms of Biochemical Markers')
plt.show()

# %%
# Plot box plots for each column
df[columns_to_visualize].plot(kind='box', subplots=True, layout=(2, 5), figsize=(15, 10), sharex=False, sharey=False)
plt.suptitle('Box Plots of Biochemical Markers')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 2
#       1 # Plot box plots for each column
# ----> 2 df[columns_to_visualize].plot(kind='box', subplots=True, layout=(2, 5), figsize=(15, 10), sharex=False, sharey=False)
#       3 plt.suptitle('Box Plots of Biochemical Markers')
#       4 plt.show()
#
# NameError: name 'columns_to_visualize' is not defined

# %%
import seaborn as sns

# Plot pair plots for the selected columns
sns.pairplot(df[columns_to_visualize])
plt.suptitle('Pair Plots of Biochemical Markers', y=1.02)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
